# %% [raw]
# import pandas as pd
# import os
#
# # List of file paths
# file_paths = [
#     "2023_8_20_00_34_04_ale_airraid-v5.csv",
#     "2023_8_20_01_28_10_ale_asterix-v5.csv",
#     "2023_8_20_02_44_06_ale_asteroids-v5.csv",
#     "2023_8_20_04_21_00_ale_bowling-v5.csv",
#     "2023_8_20_06_08_43_ale_breakout-v5.csv",
#     "2023_8_20_08_02_46_ale_demonattack-v5.csv",
#     "2023_8_20_10_13_31_ale_freeway-v5.csv",
#     "2023_8_20_12_38_26_ale_gravitar-v5.csv",
#     "2023_8_20_15_14_53_ale_jamesbond-v5.csv",
#     "2023_8_20_16_38_56_ale_montezumarevenge-v5.csv",
#     "2023_8_20_18_29_04_ale_mspacman-v5.csv",
#     "2023_8_20_20_32_48_ale_pong-v5.csv",
#     "2023_8_20_22_57_32_ale_privateeye-v5.csv",
#     "2023_8_21_01_56_24_ale_qbert-v5.csv",
#     "2023_8_21_05_18_39_ale_seaquest-v5.csv",
#     "2023_8_21_07_34_42_ale_spaceinvaders-v5.csv",
#     "2023_8_21_08_31_23_ale_venture-v5.csv",
#     "2023_8_21_10_02_20_ale_wizardofwor-v5.csv",
#     "2023_8_21_12_00_08_ale_yarsrevenge-v5.csv",
#     "2023_8_21_14_37_31_ale_zaxxon-v5.csv"
# ]
#
# # Initialize an empty list to store DataFrames
# dfs = []
#
# # Loop through file paths and read CSV files into DataFrames
# for file_path in file_paths:
#     full_path = os.path.join('.', file_path)  # Adjust the path if needed
#     df = pd.read_csv(full_path)
#     dfs.append(df)
#
# # Concatenate DataFrames together
# merged_df = pd.concat(dfs, ignore_index=True)
#
# # Save the merged DataFrame as a new CSV file
# merged_df.to_csv("reward_capacity.csv", index=False)

# %%
image_paths = [
"Definitions/ale_airraid-v5_100k_reward",
"Definitions/ale_airraid-v5_10k_reward",
"Definitions/ale_airraid-v5_1k_reward",
"Definitions/ale_airraid-v5_1M_reward",
"Definitions/ale_airraid-v5_500k_reward",
"Definitions/ale_airraid-v5_500_reward",
"Definitions/ale_airraid-v5_50k_reward",
"Definitions/ale_airraid-v5_5k_reward",
"Definitions/ale_asterix-v5_100k_reward",
"Definitions/ale_asterix-v5_10k_reward",
"Definitions/ale_asterix-v5_1k_reward",
"Definitions/ale_asterix-v5_1M_reward",
"Definitions/ale_asterix-v5_500k_reward",
"Definitions/ale_asterix-v5_500_reward",
"Definitions/ale_asterix-v5_50k_reward",
"Definitions/ale_asterix-v5_5k_reward",
"Definitions/ale_asteroids-v5_100k_reward",
"Definitions/ale_asteroids-v5_10k_reward",
"Definitions/ale_asteroids-v5_1k_reward",
"Definitions/ale_asteroids-v5_1M_reward",
"Definitions/ale_asteroids-v5_500k_reward",
"Definitions/ale_asteroids-v5_500_reward",
"Definitions/ale_asteroids-v5_50k_reward",
"Definitions/ale_asteroids-v5_5k_reward",
"Definitions/ale_bowling-v5_100k_reward",
"Definitions/ale_bowling-v5_10k_reward",
"Definitions/ale_bowling-v5_1k_reward",
"Definitions/ale_bowling-v5_1M_reward",
"Definitions/ale_bowling-v5_500k_reward",
"Definitions/ale_bowling-v5_500_reward",
"Definitions/ale_bowling-v5_50k_reward",
"Definitions/ale_bowling-v5_5k_reward",
"Definitions/ale_breakout-v5_100k_reward",
"Definitions/ale_breakout-v5_10k_reward",
"Definitions/ale_breakout-v5_1k_reward",
"Definitions/ale_breakout-v5_1M_reward",
"Definitions/ale_breakout-v5_500k_reward",
"Definitions/ale_breakout-v5_500_reward",
"Definitions/ale_breakout-v5_50k_reward",
"Definitions/ale_breakout-v5_5k_reward",
"Definitions/ale_demonattack-v5_100k_reward",
"Definitions/ale_demonattack-v5_10k_reward",
"Definitions/ale_demonattack-v5_1k_reward",
"Definitions/ale_demonattack-v5_1M_reward",
"Definitions/ale_demonattack-v5_500k_reward",
"Definitions/ale_demonattack-v5_500_reward",
"Definitions/ale_demonattack-v5_50k_reward",
"Definitions/ale_demonattack-v5_5k_reward",
"Definitions/ale_freeway-v5_100k_reward",
"Definitions/ale_freeway-v5_10k_reward",
"Definitions/ale_freeway-v5_1k_reward",
"Definitions/ale_freeway-v5_1M_reward",
"Definitions/ale_freeway-v5_500k_reward",
"Definitions/ale_freeway-v5_500_reward",
"Definitions/ale_freeway-v5_50k_reward",
"Definitions/ale_freeway-v5_5k_reward",
"Definitions/ale_gravitar-v5_100k_reward",
"Definitions/ale_gravitar-v5_10k_reward",
"Definitions/ale_gravitar-v5_1k_reward",
"Definitions/ale_gravitar-v5_1M_reward",
"Definitions/ale_gravitar-v5_500k_reward",
"Definitions/ale_gravitar-v5_500_reward",
"Definitions/ale_gravitar-v5_50k_reward",
"Definitions/ale_gravitar-v5_5k_reward",
"Definitions/ale_jamesbond-v5_100k_reward",
"Definitions/ale_jamesbond-v5_10k_reward",
"Definitions/ale_jamesbond-v5_1k_reward",
"Definitions/ale_jamesbond-v5_1M_reward",
"Definitions/ale_jamesbond-v5_500k_reward",
"Definitions/ale_jamesbond-v5_500_reward",
"Definitions/ale_jamesbond-v5_50k_reward",
"Definitions/ale_jamesbond-v5_5k_reward",
"Definitions/ale_montezumarevenge-v5_100k_reward",
"Definitions/ale_montezumarevenge-v5_10k_reward",
"Definitions/ale_montezumarevenge-v5_1k_reward",
"Definitions/ale_montezumarevenge-v5_1M_reward",
"Definitions/ale_montezumarevenge-v5_500k_reward",
"Definitions/ale_montezumarevenge-v5_500_reward",
"Definitions/ale_montezumarevenge-v5_50k_reward",
"Definitions/ale_montezumarevenge-v5_5k_reward",
"Definitions/ale_mspacman-v5_100k_reward",
"Definitions/ale_mspacman-v5_10k_reward",
"Definitions/ale_mspacman-v5_1k_reward",
"Definitions/ale_mspacman-v5_1M_reward",
"Definitions/ale_mspacman-v5_500k_reward",
"Definitions/ale_mspacman-v5_500_reward",
"Definitions/ale_mspacman-v5_50k_reward",
"Definitions/ale_mspacman-v5_5k_reward,
]

subfigure_template = r"""
\begin{subfigure}{0.2\textwidth}
    \includegraphics[width=\linewidth]{%s}
    \caption{Chart %d}
\end{subfigure}
"""

latex_code = ""

for idx, path in enumerate(image_paths, start=1):
    latex_code += subfigure_template % (path, idx)

# Complete the LaTeX document
latex_document = r"""
\documentclass{article}
\usepackage{graphicx}
\usepackage{subcaption}

\begin{document}

\begin{figure}[htbp]
    \centering
    % Insert subfigure blocks here
    % ...

    \caption{Line Chart Grid}
    \label{fig:chart_grid}
\end{figure}

\end{document}
"""

# Insert the generated subfigure blocks into the LaTeX document
latex_document = latex_document.replace('% Insert subfigure blocks here', latex_code)

print(latex_document)
