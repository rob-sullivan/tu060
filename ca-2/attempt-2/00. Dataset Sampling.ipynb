# %% [markdown]
# # Data Sampling
# This notebook allows sampling of a csv file without loading the entire file into memory.

# %%
from google.colab import drive
import csv
import sys
import pandas as pd
import random

from IPython.display import clear_output #clear print during loops

# %%
#get data from google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/data/guardian_articles.csv' # large dataset

# %%
csv.field_size_limit(sys.maxsize) #avoids _csv.Error: field larger than field limit (131072)
# Out:
# 131072

# %%
# Open the CSV file in read-only mode
with open(filename, 'r') as file:

    # Create a CSV reader object
    reader = csv.reader(file)

    # Peak at the first row to understand headers
    for i in range(1):
        try:
            row = next(reader)
            for items in row:
              item = items.split(", ")
              print(item)
            #print(row)
        except StopIteration:
            break
    #loop through file to get total rows
    row_count = sum(1 for row in reader) #may take some time with big files
# Out:
# ['article_id']
# ['sectionName']
# ['webTitle']
# ['webUrl']
# ['bodyContent']
# ['webPublicationDate']
# ['id']

# %%
print(str(row_count) + " rows found in the file.")
# Out:
# 149839 rows found in the file.

# %%
sample_size_perc = 0.1 # 10%

# %%
sample_size = int(row_count*sample_size_perc) #get 10%
print(str(sample_size) + " rows will be sampled")
# Out:
# 14983 rows will be sampled

# %%
# Create empty dataframe
df = pd.DataFrame(columns=['article_id', 'sectionName', 'webTitle', 'webUrl', 'bodyContent', 'webPublicationDate', 'id'])
df.head()
# Out:
# Empty DataFrame
# Columns: [article_id, sectionName, webTitle, webUrl, bodyContent, webPublicationDate, id]
# Index: []

# %%
sample_ids = []
for i in range(0,sample_size):
  n = random.randint(1, row_count)
  while n in sample_ids: #resample if duplicate
    n = random.randint(1, row_count)
  sample_ids.append(n)
sample_rows = sorted(sample_ids)
print(str(len(sample_rows)) + " row ids to sample.")
# Out:
# 14983 row ids to sample.

# %%
for i in range(10):#check some of the sample row ids
  print(sample_rows[i])
# Out:
# 8
# 23
# 26
# 45
# 59
# 79
# 95
# 152
# 160
# 171

# %%
# Open CSV file again in read-only mode but this time get samples
with open(filename, 'r') as file:

    # Create a CSV reader object
    reader = csv.reader(file)

    # Read the first row to understand headers
    for i in range(row_count):
        clear_output(wait=True)
        try:
            row = next(reader)
            if i in sample_rows:
              #items = #[item.split(",") for item in row]
              df.loc[len(df)] = row[:]
        except StopIteration:
            break
        print(str(round((i/row_count)*100, 2)) + "% ("+ str(i) + "/" + str(row_count) + ") complete") #may take some time
# Out:
# 100.0% (149838/149839) complete

# %%
len(df)
# Out:
# 14983

# %%
df.head()
# Out:
#                                           article_id     sectionName  \
# 0  football/2016/jan/31/saido-berahino-west-brom-...        Football
# 1  sport/2016/jan/31/angelique-kerber-serena-will...           Sport
# 2  world/2016/feb/01/the-australian-family-who-ha...      World news
# 3  sport/2016/jan/31/worcester-exeter-premiership...           Sport
# 4  artanddesign/2016/jan/31/exposed-photographys-...  Art and design
#
#                                             webTitle  \
# 0  Saido Berahino has right attitude but he’s not...
# 1  Angelique Kerber now aims to dislodge Serena W...
# 2  The family building a refugee haven in the sha...
# 3  Exeter keep Saracens in their sights with bonu...
# 4              Exposed: photography's fabulous fakes
#
#                                               webUrl  \
# 0  https://www.theguardian.com/football/2016/jan/...
# 1  https://www.theguardian.com/sport/2016/jan/31/...
# 2  https://www.theguardian.com/world/2016/feb/01/...
# 3  https://www.theguardian.com/sport/2016/jan/31/...
# 4  https://www.theguardian.com/artanddesign/2016/...
#
#                                          bodyContent    webPublicationDate  id
# 0  Tony Pulis hopes his only transfer business be...  2016-01-31T22:30:10Z   8
# 1  Gone midnight and Angelique Kerber was conduct...  2016-01-31T21:59:09Z  23
# 2  On 9 June 2014 Queenslander and charity worker...  2016-01-31T21:27:40Z  26
# 3  There is no need for calculators this week but...  2016-01-31T19:12:58Z  45
# 4  In 1840, Hippolyte Bayard, a pioneer of early ...  2016-01-31T18:00:03Z  59

# %%
df.columns
# Out:
# Index(['webTitle', 'bodyContent', 'sectionName'], dtype='object')

# %%
#drop the columns we don't need for our analysis/modelling
df = df.drop(columns=['article_id', 'webUrl', 'webPublicationDate', 'id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d43085c83ae9> in <cell line: 2>()
#       1 #drop the columns we don't need for our analysis/modelling
# ----> 2 df = df.drop(columns=['article_id', 'webUrl', 'webPublicationDate', 'id'], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['article_id', 'webUrl', 'webPublicationDate', 'id'] not found in axis"

# %%
df.columns
# Out:
# Index(['webTitle', 'bodyContent', 'sectionName'], dtype='object')

# %%
#reorder columns so we have our features X and our target y
df = df[['webTitle', 'bodyContent', 'sectionName']]

# %%
df.columns
# Out:
# Index(['webTitle', 'bodyContent', 'sectionName'], dtype='object')

# %%
#check missing data
df.isnull().sum() #none missing
# Out:
# webTitle       0
# bodyContent    0
# sectionName    0
# dtype: int64

# %%
df.webTitle[50]
# Out:
# 'How do I ... know if I have a mental illness?'

# %%
df.bodyContent[50]
# Out:
# 'Mental health problems affect one in four of us at any one time. Though accurate figures can be difficult to obtain, it is estimated that 450 million people worldwide have a mental health problem. What is mental illness? There are more than 200 clinically diagnosable mental health conditions, very roughly organised into five major categories. These are: mood disorders, anxiety disorders, schizophrenia and psychotic disorders, eating disorders and dementia. Depression is the most common mental illness. The World Health Organisation estimates that by 2020 depression will be the second leading cause of disability globally, after heart disease. Other common mental illnesses include: general anxiety disorder, bipolar disorder, schizophrenia and anorexia. Lesser known, but just as debilitating, conditions include trichotillomania (a compulsion to pull out one’s hair) and pica (the eating of non-edible items). Different conditions are more prevalent in different parts of the globe. Obsessive compulsive disorder is three times more likely to occur in Latin America than in Africa. Japan has high rates of schizophrenia. How do I know if I am unwell? It is normal to feel sad, angry, upset, frustrated, confused – so how do we know if what we’re experiencing is indicative of a more serious problem? “When it starts to screw up our life,” says Simon Wessely, president of the Royal College of Psychiatrists and chair of psychological medicine at King’s College London. “When we are not just anxious – we can’t go into a shop, can’t use the tube, can’t talk to someone without crippling panic attacks. Or when we are not just sad, we can’t get out of bed, we eat too little or too much, when we can’t concentrate on the simplest of tasks, and when we start to think about harming ourselves.” We all have worries about our appearance, but spending hours in front of a mirror or obsessing on a specific perceived default, to the detriment of a social life, could be a sign of body dysmorphic disorder or another anxiety issue. Shifts in appetite (whether increased or decreased), sleep pattern (again, more or less), a loss of interest in pleasurable activities (including sex) can all be signs of depression. Jonny Benjamin, a film-maker, has schizoaffective disorder, which combines elements of schizophrenia, mania and depression. Benjamin used to hear voices as a child, a sort of internal commentary on events. “The voice changed and it became more of a devil. It would challenge me to do certain things – so I might have to move an object from one place to the other, or I would be punished,” he says about the onset of his illness. Of course, not everyone with a mental illness will hear voices. Not everybody who is depressed will cry. Symptoms manifest themselves in various ways. Conditions will sometimes also present differently according to age and gender. The other thing to remember is that, as Wessely explains, “some people lack insight into the fact that they are ill, but it is obvious to everyone else around them”. If people you trust suggest you are becoming unwell, it might be worth consulting your GP. What causes mental illness? As with a lot of things, mental illness seems to be a combination of nature and nurture. However, there are genetic risk factors for certain conditions, such as schizophrenia and bipolar disorder. But the fact that some conditions run in families may be as much to do with social factors as genes. Rates of mental illness tend to double after humanitarian disasters and changes in our lives or physical illness might also contribute to the onset of mental ill health. But there is no specific catalyst for any mental health condition.\nWill I be diagnosed? It can be really helpful to look up information online when curious about mental health, but be careful of self-diagnosis. In the same way you wouldn’t entrust a Magic 8 ball to confirm a pregnancy, you wouldn’t entrust WebMD to tell you what’s going on in your brain. It might be us ...

# %%
df.sectionName[50]
# Out:
# 'UK news'

# %%
savefilename = filename[:-4]+ "_" + str(int(round(sample_size_perc*100,0))) + "_perc.csv"
print(savefilename)
# Out:
# /content/drive/MyDrive/data/guardian_articles_10_perc.csv

# %%
#save sample to csv file
df.to_csv(savefilename, sep=',', encoding='utf-8', index=False)
