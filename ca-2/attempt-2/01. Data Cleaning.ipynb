# %% [markdown]
# # Import Libaries
# In this notebook sample data is improted and cleaned. The new cleaned data is then divided into different types of text representation: BOW, Text Vectors and raw text.

# %%
#from google.colab import drive, files

import pandas as pd

#word cleaning
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

#data prep and dl modelling
import tensorflow as tf


#save encoded data
from numpy import savetxt

#used to count words
from collections import Counter

# %%
nltk.download('stopwords') #to remove common words
nltk.download('wordnet') #for WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#get data from google drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Utility Functions

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text): #ref:https://towardsdatascience.com/multi-class-text-classification-with-lstm-1590bee1bd17
    """
      outputs a cleaned string of text from an input string of text
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing.
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwords from text
    lemmatizer.lemmatize(text) # reduce to root word
    return text

truncate = 128
def truncate_text(text):
    text = text[:truncate] # reduce string length

# %% [markdown]
# # Import Sample

# %%
df = pd.read_csv('/content/drive/MyDrive/data/guardian_articles_10_perc.csv')

# %%
df['webTitle'] = df['webTitle'].astype(str)

# %%
df['bodyContent'] = df['bodyContent'].astype(str)

# %%
df['sectionName'] = df['sectionName'].astype(str)

# %%
df.webTitle[50]
# Out:
# 'How do I ... know if I have a mental illness?'

# %%
df.bodyContent[50]
# Out:
# 'Mental health problems affect one in four of us at any one time. Though accurate figures can be difficult to obtain, it is estimated that 450 million people worldwide have a mental health problem. What is mental illness? There are more than 200 clinically diagnosable mental health conditions, very roughly organised into five major categories. These are: mood disorders, anxiety disorders, schizophrenia and psychotic disorders, eating disorders and dementia. Depression is the most common mental illness. The World Health Organisation estimates that by 2020 depression will be the second leading cause of disability globally, after heart disease. Other common mental illnesses include: general anxiety disorder, bipolar disorder, schizophrenia and anorexia. Lesser known, but just as debilitating, conditions include trichotillomania (a compulsion to pull out one’s hair) and pica (the eating of non-edible items). Different conditions are more prevalent in different parts of the globe. Obsessive compulsive disorder is three times more likely to occur in Latin America than in Africa. Japan has high rates of schizophrenia. How do I know if I am unwell? It is normal to feel sad, angry, upset, frustrated, confused – so how do we know if what we’re experiencing is indicative of a more serious problem? “When it starts to screw up our life,” says Simon Wessely, president of the Royal College of Psychiatrists and chair of psychological medicine at King’s College London. “When we are not just anxious – we can’t go into a shop, can’t use the tube, can’t talk to someone without crippling panic attacks. Or when we are not just sad, we can’t get out of bed, we eat too little or too much, when we can’t concentrate on the simplest of tasks, and when we start to think about harming ourselves.” We all have worries about our appearance, but spending hours in front of a mirror or obsessing on a specific perceived default, to the detriment of a social life, could be a sign of body dysmorphic disorder or another anxiety issue. Shifts in appetite (whether increased or decreased), sleep pattern (again, more or less), a loss of interest in pleasurable activities (including sex) can all be signs of depression. Jonny Benjamin, a film-maker, has schizoaffective disorder, which combines elements of schizophrenia, mania and depression. Benjamin used to hear voices as a child, a sort of internal commentary on events. “The voice changed and it became more of a devil. It would challenge me to do certain things – so I might have to move an object from one place to the other, or I would be punished,” he says about the onset of his illness. Of course, not everyone with a mental illness will hear voices. Not everybody who is depressed will cry. Symptoms manifest themselves in various ways. Conditions will sometimes also present differently according to age and gender. The other thing to remember is that, as Wessely explains, “some people lack insight into the fact that they are ill, but it is obvious to everyone else around them”. If people you trust suggest you are becoming unwell, it might be worth consulting your GP. What causes mental illness? As with a lot of things, mental illness seems to be a combination of nature and nurture. However, there are genetic risk factors for certain conditions, such as schizophrenia and bipolar disorder. But the fact that some conditions run in families may be as much to do with social factors as genes. Rates of mental illness tend to double after humanitarian disasters and changes in our lives or physical illness might also contribute to the onset of mental ill health. But there is no specific catalyst for any mental health condition.\nWill I be diagnosed? It can be really helpful to look up information online when curious about mental health, but be careful of self-diagnosis. In the same way you wouldn’t entrust a Magic 8 ball to confirm a pregnancy, you wouldn’t entrust WebMD to tell you what’s going on in your brain. It might be us ...

# %%
df.sectionName[50]
# Out:
# 'UK news'

# %% [markdown]
# # Clean Sample Data

# %%
df.iloc[:, 0] = df.iloc[:,0].apply(clean_text)

# %%
df.iloc[:, 1] = df.iloc[:,1].apply(clean_text)

# %%
df.iloc[:, 2] = df.iloc[:,2].apply(clean_text)

# %%
df.webTitle[50]
# Out:
# 'know mental illness'

# %%
df.bodyContent[50]
# Out:
# 'mental health problems affect one four us one time though accurate figures difficult obtain estimated 450 million people worldwide mental health problem mental illness 200 clinically diagnosable mental health conditions roughly organised five major categories mood disorders anxiety disorders schizophrenia psychotic disorders eating disorders dementia depression common mental illness world health organisation estimates 2020 depression second leading cause disability globally heart disease common mental illnesses include general anxiety disorder bipolar disorder schizophrenia anorexia lesser known debilitating conditions include trichotillomania compulsion pull ones hair pica eating nonedible items different conditions prevalent different parts globe obsessive compulsive disorder three times likely occur latin america africa japan high rates schizophrenia know unwell normal feel sad angry upset frustrated confused know experiencing indicative serious problem starts screw life says simon wessely president royal college psychiatrists chair psychological medicine kings college london anxious cant go shop cant use tube cant talk someone without crippling panic attacks sad cant get bed eat little much cant concentrate simplest tasks start think harming worries appearance spending hours front mirror obsessing specific perceived default detriment social life could sign body dysmorphic disorder another anxiety issue shifts appetite whether increased decreased sleep pattern less loss interest pleasurable activities including sex signs depression jonny benjamin filmmaker schizoaffective disorder combines elements schizophrenia mania depression benjamin used hear voices child sort internal commentary events voice changed became devil would challenge certain things might move object one place would punished says onset illness course everyone mental illness hear voices everybody depressed cry symptoms manifest various ways conditions sometimes also present differently according age gender thing remember wessely explains people lack insight fact ill obvious everyone else around people trust suggest becoming unwell might worth consulting gp causes mental illness lot things mental illness seems combination nature nurture however genetic risk factors certain conditions schizophrenia bipolar disorder fact conditions run families may much social factors genes rates mental illness tend double humanitarian disasters changes lives physical illness might also contribute onset mental ill health specific catalyst mental health conditionwill diagnosed really helpful look information online curious mental health careful selfdiagnosis way wouldnt entrust magic 8 ball confirm pregnancy wouldnt entrust webmd tell whats going brain might useful however jot thoughts visiting gp possible may referred specialist care come contact community psychiatric nurses psychotherapists take long time diagnosed mental health condition average bipolar disorder 132 years wessely warns diagnosis beginning end everyone see shares something someone else illness ocd attention deficit hyperactivity disorder adhd posttraumatic stress disorder ptsd everyone also individual psychiatry bringing together come best understanding person get ill disorder time treated ideas around mental illness thankfully changed greatly course history instance womens hysteria longer treated vibrators mental health conditions treated medication therapeutic intervention numerous issues around treatments research mental health drugs chronically underfunded psychiatrist recruitment alltime low therapeutic discipline panacea wessely says working needs individual recognising pattern drawing results research around world say example claustrophobia inability tolerate confined spaces know patients literature cognitive behavioural therapy going help taking sedative like valium wont recover yes people recover entirely periods mental illness many people learn manage chronic conditions try remember recently diagnose ...

# %%
df.sectionName[50]
# Out:
# 'uk news'

# %%
df["webTitle_bodyContent"] = df['webTitle'].astype(str) +" "+ df['bodyContent'].astype(str)

# %%
#drop the columns we don't need for further analysis/modelling
df = df.drop(columns=['bodyContent'])

# %%
#reorder columns so we have our features X and our target y
df = df[['webTitle', 'webTitle_bodyContent', 'sectionName']]

# %%
df.head()
# Out:
#                                             webTitle  \
# 0  saido berahino right attitude hes fit says wes...
# 1  angelique kerber aims dislodge serena williams...
# 2                family building refugee shadow isis
# 3  exeter keep saracens sights bonus point win wo...
# 4                exposed photographys fabulous fakes
#
#                                 webTitle_bodyContent sectionName
# 0  saido berahino right attitude hes fit says wes...    football
# 1  angelique kerber aims dislodge serena williams...       sport
# 2  family building refugee shadow isis 9 june 201...  world news
# 3  exeter keep saracens sights bonus point win wo...       sport
# 4  exposed photographys fabulous fakes 1840 hippo...  art design

# %% [markdown]
# # Explore Data

# %%
# To define our vocab we need to count how many unique words are in the dataset.
# since we combine webTitle and bodyContent we can use the combined column
feature_words = Counter()
df['webTitle'].str.lower().str.split().apply(feature_words.update)

max_feature_words = len(feature_words)
print("webTitle vocab size: " + str(max_feature_words))
# Out:
# webTitle vocab size: 23681

# %%
feature_words = Counter()
df['webTitle_bodyContent'].str.lower().str.split().apply(feature_words.update)

max_feature_words = len(feature_words)
print("webTitle_bodyContent vocab size: " + str(max_feature_words))
# Out:
# webTitle_bodyContent vocab size: 200451

# %%
target_words = Counter()
df['sectionName'].str.lower().str.split().apply(target_words.update)

max_target_classes = len(target_words)
print("class size: " + str(max_target_classes))
# Out:
# class size: 121

# %%
# we have 14,983 instances
len(df['sectionName'])
# Out:
# 14983

# %%
# Find how many words per row a.k.a the sequence length, but exclude counting spaces
# we will use this to pad the output
seq_len_wt = int(df.iloc[:, 0].map(len).max())
seq_len_wt_bc = int(df.iloc[:, 1].map(len).max())
print("WebTitle: " + str(seq_len_wt) + ", webTitlebodyContent: " + str(seq_len_wt_bc)) #max length of each example
# Out:
# WebTitle: 128, webTitlebodyContent: 59755

# %% [markdown]
# # Save Cleaned Datasets
# Below we save our cleaned datasets to disk so we can reuse them later when building our models. Unfortunately these sets are much larger than the orginal 10% sample we took. This is one of the drawbacks of text representation such as bag-of-words. Code for saving these files were all ran individually and then commented out to not exceed colab free account restrictions.

# %%
# Save the pandas DataFrame to a CSV file
df.webTitle.to_csv('./data/X_raw_wt.csv', index=False)#822.4kb #/content/drive/MyDrive

# %%
# Save the pandas DataFrame to a CSV file
df.webTitle_bodyContent.to_csv('./data/X_raw_wt_bc.csv', index=False) #/content/drive/MyDrive/

# %%
# Save the pandas DataFrame to a CSV file
df.sectionName.to_csv('./data/y_raw.csv', index=False) #/content/drive/MyDrive

# %% [markdown]
# ## Text to Sequence

# %%
wt_sequences = encode_wt.texts_to_sequences(df.webTitle.values)
X_t2s_wt = pad_sequences(wt_sequences, padding='post', truncating='post', maxlen=seq_len_wt)

# %%
X_t2s_wt
# Out:
# array([[11115, 11116,   118, ...,     0,     0,     0],
#        [11119, 11120,  1430, ...,     0,     0,     0],
#        [  105,  1775,   534, ...,     0,     0,     0],
#        ...,
#        [ 3954,   215,   252, ...,     0,     0,     0],
#        [ 1536,  4797,    42, ...,     0,     0,     0],
#        [11006,   911, 10361, ...,     0,     0,     0]], dtype=int32)

# %%
X_t2s_wt.shape
# Out:
# (14983, 128)

# %%
wt_bc_sequences = encode_wt_bc.texts_to_sequences(df.webTitle_bodyContent.values)
X_t2s_wt_bc = pad_sequences(wt_bc_sequences, padding='post', truncating='post', maxlen=seq_len_wt_bc)

# %%
X_t2s_wt_bc
# Out:
# array([[42542, 37092,    62, ...,     0,     0,     0],
#        [26864, 22351,  3413, ...,     0,     0,     0],
#        [   79,   576,  2128, ...,     0,     0,     0],
#        ...,
#        [11541,   662,  1212, ...,     0,     0,     0],
#        [ 3002, 10330,   206, ...,     0,     0,     0],
#        [12301,   211, 24372, ...,     0,     0,     0]], dtype=int32)

# %%
X_t2s_wt_bc.shape
# Out:
# (14983, 59755)
